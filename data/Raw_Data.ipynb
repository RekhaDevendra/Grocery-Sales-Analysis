# %%
import random
import csv

# Define constants
dates = ['2023-12-01', '2023-08-01', '2023-02-01']
stores = {
    1: {'name': 'Zehrs', 'type': 'Retail'},
    2: {'name': 'Costco', 'type': 'Wholesale'},
    3: {'name': 'FreshCo', 'type': 'Retail'}
}
products = [
    {'key': 'P101', 'name': 'Apples', 'department': 'Produce'},
    {'key': 'P102', 'name': 'Oranges', 'department': 'Produce'},
    {'key': 'P103', 'name': 'Chips', 'department': 'Snacks'},
    {'key': 'P104', 'name': 'Milk', 'department': 'Dairy'},
    {'key': 'P105', 'name': 'Eggs', 'department': 'Dairy'},
    {'key': 'P106', 'name': 'Processed Meat', 'department': 'Meat'},
    {'key': 'P107', 'name': 'Fresh Fish', 'department': 'Seafood'},
    {'key': 'P108', 'name': 'Chocolate', 'department': 'Snacks'},
    {'key': 'P109', 'name': 'Bread', 'department': 'Bakery'},
    {'key': 'P110', 'name': 'Cereal', 'department': 'Breakfast'},
    {'key': 'P111', 'name': 'Potatoes', 'department': 'Produce'},
    {'key': 'P112', 'name': 'Onions', 'department': 'Produce'},
    {'key': 'P113', 'name': 'Tomatoes', 'department': 'Produce'},
    {'key': 'P114', 'name': 'Carrots', 'department': 'Produce'},
    {'key': 'P115', 'name': 'Bananas', 'department': 'Produce'},
    {'key': 'P116', 'name': 'Strawberries', 'department': 'Produce'},
    {'key': 'P117', 'name': 'Blueberries', 'department': 'Produce'},
    {'key': 'P118', 'name': 'Lettuce', 'department': 'Produce'},
    {'key': 'P119', 'name': 'Spinach', 'department': 'Produce'},
    {'key': 'P120', 'name': 'Ice Cream', 'department': 'Frozen Foods'},
    {'key': 'P121', 'name': 'Pizza', 'department': 'Frozen Foods'},
    {'key': 'P122', 'name': 'Juice', 'department': 'Beverages'},
    {'key': 'P123', 'name': 'Coffee', 'department': 'Beverages'},
    {'key': 'P124', 'name': 'Tea', 'department': 'Beverages'},
    {'key': 'P125', 'name': 'Beer', 'department': 'Alcohol'},
    {'key': 'P126', 'name': 'Wine', 'department': 'Alcohol'},
    {'key': 'P127', 'name': 'Chicken', 'department': 'Meat'},
    {'key': 'P128', 'name': 'Beef', 'department': 'Meat'},
    {'key': 'P129', 'name': 'Pork', 'department': 'Meat'},
    {'key': 'P130', 'name': 'Turkey', 'department': 'Meat'},
    {'key': 'P131', 'name': 'Salmon', 'department': 'Seafood'},
    {'key': 'P132', 'name': 'Shrimp', 'department': 'Seafood'},
    {'key': 'P133', 'name': 'Crab', 'department': 'Seafood'},
    {'key': 'P134', 'name': 'Lobster', 'department': 'Seafood'},
    {'key': 'P135', 'name': 'Pasta', 'department': 'Pantry'},
    {'key': 'P136', 'name': 'Rice', 'department': 'Pantry'},
    {'key': 'P137', 'name': 'Beans', 'department': 'Canned Goods'},
    {'key': 'P138', 'name': 'Soup', 'department': 'Canned Goods'},
    {'key': 'P139', 'name': 'Peanut Butter', 'department': 'Pantry'},
    {'key': 'P140', 'name': 'Jam', 'department': 'Pantry'},
    {'key': 'P141', 'name': 'Olive Oil', 'department': 'Condiments'},
    {'key': 'P142', 'name': 'Vinegar', 'department': 'Condiments'},
    {'key': 'P143', 'name': 'Ketchup', 'department': 'Condiments'},
    {'key': 'P144', 'name': 'Mustard', 'department': 'Condiments'},
    {'key': 'P145', 'name': 'Mayonnaise', 'department': 'Condiments'},
    {'key': 'P146', 'name': 'Pickles', 'department': 'Condiments'},
    {'key': 'P147', 'name': 'Salsa', 'department': 'Condiments'},
    {'key': 'P148', 'name': 'Chips', 'department': 'Snacks'},
    {'key': 'P149', 'name': 'Popcorn', 'department': 'Snacks'},
    {'key': 'P150', 'name': 'Cookies', 'department': 'Snacks'}
]
ages = ['< 30', '> 30']
incomes = ['> 20k', '< 20k']
veg_non_veg = ['Veg', 'Non-Veg']
purchased = ['Yes', 'No']
season_offers = {
    '2023-12-01': 'Yes',  # Winter offer
    '2023-08-01': 'Yes',  # Summer offer
    '2023-02-01': 'No'    # Spring offer
}

# Generate dataset
dataset = []

for _ in range(500):
    date = random.choice(dates)
    store_key = random.choice(list(stores.keys()))
    store_name = stores[store_key]['name']
    store_type = stores[store_key]['type']
    product = random.choice(products)
    product_key = product['key']
    product_name = product['name']
    product_department = product['department']
    transaction_number = str(random.randint(1000, 9999)) if random.random() > 0.1 else '0000'  # 10% chance of not purchased
    dollar_sales = round(random.uniform(1, 50), 2)
    units_sold = random.randint(1, 10)
    age = random.choice(ages)
    income = random.choice(incomes)
    veg_or_non_veg = random.choice(veg_non_veg)
    purchased_status = 'Yes' if transaction_number != '0000' else 'No'
    offer = season_offers[date]

    row = [
        date, store_key, store_name, store_type,
        product_key, product_name, product_department,
        transaction_number, dollar_sales, units_sold,
        age, income, veg_or_non_veg, purchased_status, offer
    ]
    dataset.append(row)

# Write dataset to CSV
headers = [
    'Date Key', 'Store Key', 'Store Name', 'Whole Sale or Retail Store',
    'Product Key', 'Product Name', 'Product Department',
    'Transaction #', 'Dollar Sales', 'Units Sold',
    'Age', 'Income', 'Veg or Non-Veg', 'Purchased', 'Offer'
]

with open('grocery_sales_dataset.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(headers)
    writer.writerows(dataset)

print("Dataset generation completed. File 'grocery_sales_dataset.csv' created.")
# Out:
# Dataset generation completed. File 'grocery_sales_dataset.csv' created.

# %%
import random
import csv

# Define constants
dates = ['2023-12-01', '2023-08-01', '2023-02-01']
stores = {
    1: {'name': 'Zehrs', 'type': 'Retail'},
    2: {'name': 'Costco', 'type': 'Wholesale'},
    3: {'name': 'FreshCo', 'type': 'Retail'}
}
products = [
    {'key': 'P101', 'name': 'Apples', 'department': 'Produce'},
    {'key': 'P102', 'name': 'Oranges', 'department': 'Produce'},
    {'key': 'P103', 'name': 'Chips', 'department': 'Snacks'},
    {'key': 'P104', 'name': 'Milk', 'department': 'Dairy'},
    {'key': 'P105', 'name': 'Eggs', 'department': 'Dairy'},
    {'key': 'P106', 'name': 'Processed Meat', 'department': 'Meat'},
    {'key': 'P107', 'name': 'Fresh Fish', 'department': 'Seafood'},
    {'key': 'P108', 'name': 'Chocolate', 'department': 'Snacks'},
    {'key': 'P109', 'name': 'Bread', 'department': 'Bakery'},
    {'key': 'P110', 'name': 'Cereal', 'department': 'Breakfast'},
    {'key': 'P111', 'name': 'Potatoes', 'department': 'Produce'},
    {'key': 'P112', 'name': 'Onions', 'department': 'Produce'},
    {'key': 'P113', 'name': 'Tomatoes', 'department': 'Produce'},
    {'key': 'P114', 'name': 'Carrots', 'department': 'Produce'},
    {'key': 'P115', 'name': 'Bananas', 'department': 'Produce'},
    {'key': 'P116', 'name': 'Strawberries', 'department': 'Produce'},
    {'key': 'P117', 'name': 'Blueberries', 'department': 'Produce'},
    {'key': 'P118', 'name': 'Lettuce', 'department': 'Produce'},
    {'key': 'P119', 'name': 'Spinach', 'department': 'Produce'},
    {'key': 'P120', 'name': 'Ice Cream', 'department': 'Frozen Foods'},
    {'key': 'P121', 'name': 'Pizza', 'department': 'Frozen Foods'},
    {'key': 'P122', 'name': 'Juice', 'department': 'Beverages'},
    {'key': 'P123', 'name': 'Coffee', 'department': 'Beverages'},
    {'key': 'P124', 'name': 'Tea', 'department': 'Beverages'},
    {'key': 'P125', 'name': 'Beer', 'department': 'Alcohol'},
    {'key': 'P126', 'name': 'Wine', 'department': 'Alcohol'},
    {'key': 'P127', 'name': 'Chicken', 'department': 'Meat'},
    {'key': 'P128', 'name': 'Beef', 'department': 'Meat'},
    {'key': 'P129', 'name': 'Pork', 'department': 'Meat'},
    {'key': 'P130', 'name': 'Turkey', 'department': 'Meat'},
    {'key': 'P131', 'name': 'Salmon', 'department': 'Seafood'},
    {'key': 'P132', 'name': 'Shrimp', 'department': 'Seafood'},
    {'key': 'P133', 'name': 'Crab', 'department': 'Seafood'},
    {'key': 'P134', 'name': 'Lobster', 'department': 'Seafood'},
    {'key': 'P135', 'name': 'Pasta', 'department': 'Pantry'},
    {'key': 'P136', 'name': 'Rice', 'department': 'Pantry'},
    {'key': 'P137', 'name': 'Beans', 'department': 'Canned Goods'},
    {'key': 'P138', 'name': 'Soup', 'department': 'Canned Goods'},
    {'key': 'P139', 'name': 'Peanut Butter', 'department': 'Pantry'},
    {'key': 'P140', 'name': 'Jam', 'department': 'Pantry'},
    {'key': 'P141', 'name': 'Olive Oil', 'department': 'Condiments'},
    {'key': 'P142', 'name': 'Vinegar', 'department': 'Condiments'},
    {'key': 'P143', 'name': 'Ketchup', 'department': 'Condiments'},
    {'key': 'P144', 'name': 'Mustard', 'department': 'Condiments'},
    {'key': 'P145', 'name': 'Mayonnaise', 'department': 'Condiments'},
    {'key': 'P146', 'name': 'Pickles', 'department': 'Condiments'},
    {'key': 'P147', 'name': 'Salsa', 'department': 'Condiments'},
    {'key': 'P148', 'name': 'Chips', 'department': 'Snacks'},
    {'key': 'P149', 'name': 'Popcorn', 'department': 'Snacks'},
    {'key': 'P150', 'name': 'Cookies', 'department': 'Snacks'}
]
ages = ['< 30', '> 30']
incomes = ['> 20k', '< 20k']
purchased = ['Yes', 'No']
season_offers = {
    '2023-12-01': 'Yes',  # Winter offer
    '2023-08-01': 'Yes',  # Summer offer
    '2023-02-01': 'No'    # Spring offer
}

# Determine Veg or Non-Veg based on product department
for product in products:
    if product['department'] in ['Produce', 'Frozen Foods', 'Bakery', 'Breakfast']:
        product['veg_or_non_veg'] = 'Veg'
    else:
        product['veg_or_non_veg'] = 'Non-Veg'

# Generate dataset
dataset = []

for _ in range(500):
    date = random.choice(dates)
    store_key = random.choice(list(stores.keys()))
    store_name = stores[store_key]['name']
    store_type = stores[store_key]['type']
    product = random.choice(products)
    product_key = product['key']
    product_name = product['name']
    product_department = product['department']
    transaction_number = str(random.randint(1000, 9999)) if random.random() > 0.1 else '0000'  # 10% chance of not purchased
    dollar_sales = round(random.uniform(1, 50), 2)
    units_sold = random.randint(1, 10)
    age = random.choice(ages)
    income = random.choice(incomes)
    veg_or_non_veg = product['veg_or_non_veg']
    purchased_status = 'Yes' if transaction_number != '0000' else 'No'
    offer = season_offers[date]

    row = [
        date, store_key, store_name, store_type,
        product_key, product_name, product_department,
        transaction_number, dollar_sales, units_sold,
        age, income, veg_or_non_veg, purchased_status, offer
    ]
    dataset.append(row)

# Write dataset to CSV
headers = [
    'Date Key', 'Store Key', 'Store Name', 'Whole Sale or Retail Store',
    'Product Key', 'Product Name', 'Product Department',
    'Transaction #', 'Dollar Sales', 'Units Sold',
    'Age', 'Income', 'Veg or Non-Veg', 'Purchased', 'Offer'
]

with open('grocery_sales_dataset.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(headers)
    writer.writerows(dataset)

print("Dataset generation completed. File 'grocery_sales_dataset.csv' created.")
# Out:
# Dataset generation completed. File 'grocery_sales_dataset.csv' created.
